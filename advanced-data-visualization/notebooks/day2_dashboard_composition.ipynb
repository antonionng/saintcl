# %% [markdown]
# # Day 2: Dashboard Composition -- Segments, Geography, and Critique
#
# **Module 6: Advanced Data Visualization | AJB AI and Data Training Programme**
#
# In this notebook you will analyse customer segments, create geospatial visualizations,
# and practise the four-question critique framework.
#
# **Datasets:** `../data/customer_metrics.csv`, `../data/regional_data.csv`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

plt.rcParams.update({
    'figure.figsize': (10, 6),
    'axes.spines.top': False,
    'axes.spines.right': False,
    'font.size': 11
})

customers = pd.read_csv('../data/customer_metrics.csv')
regions = pd.read_csv('../data/regional_data.csv')

print('Customer segments:')
display(customers)
print('\nRegional data:')
display(regions)

# %% [markdown]
# ## Lab 4: Customer Segment Analysis
#
# **Task 1:** Create a horizontal bar chart comparing `revenue_per_customer` across segments,
# sorted from highest to lowest. Highlight the segment with the highest churn rate in a
# warning colour.
#
# **Task 2:** Create a scatter plot of `churn_rate` (x) vs `digital_adoption_pct` (y),
# with bubble size proportional to `customer_count`. Annotate the highest-churn segment.

# %%
# Lab 4, Task 1: Revenue per customer bar chart
# Hint: sort by revenue_per_customer, use conditional colour for highest churn segment

# YOUR CODE HERE

# %%
# Lab 4, Task 2: Churn vs digital adoption scatter plot
# Hint: use plt.scatter() with s= for size (scale customer_count for readability)

# YOUR CODE HERE

# %% [markdown]
# ## Lab 5: Geospatial Branch Analysis
#
# **Task:** Create a bubble map using latitude and longitude as axes. Size bubbles by
# `customers` and colour by `growth_pct`. Add region labels directly on the chart.
#
# **Stretch:** Create a second view coloured by `market_share_pct`.

# %%
# Lab 5: Geospatial bubble map
# Hint: plt.scatter(regions['longitude'], regions['latitude'], s=..., c=...)
# Size by area: s = regions['customers'] / scale_factor
# Add plt.colorbar() and plt.text() for labels

# YOUR CODE HERE
