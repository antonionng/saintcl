# %% [markdown]
# # Day 3: Executive Reporting -- Summary, Narrative, and Presentation
#
# **Module 6: Advanced Data Visualization | AJB AI and Data Training Programme**
#
# In this notebook you will build a complete executive reporting pack for the Head of
# Retail Banking, combining all three datasets into a coherent visual narrative.
#
# **Datasets:** `../data/branch_performance.csv`, `../data/customer_metrics.csv`, `../data/regional_data.csv`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

plt.rcParams.update({
    'figure.figsize': (10, 6),
    'axes.spines.top': False,
    'axes.spines.right': False,
    'font.size': 11
})

branches = pd.read_csv('../data/branch_performance.csv')
customers = pd.read_csv('../data/customer_metrics.csv')
regions = pd.read_csv('../data/regional_data.csv')

# %% [markdown]
# ## Lab 7: Executive Summary Page
#
# **Task 1:** Calculate and display 4 KPIs:
# - Total revenue (sum of all branch revenue)
# - Average satisfaction score
# - Top growth region (name and percentage)
# - Highest churn segment (name and rate)
#
# **Task 2:** Create a sorted branch revenue bar chart with a target reference line.
# Add an action title and a 1-sentence recommendation.

# %%
# Lab 7, Task 1: KPI calculations and display
total_revenue = branches['revenue_sar'].sum()
avg_satisfaction = branches['satisfaction_score'].mean()
top_growth_region = regions.loc[regions['growth_pct'].idxmax()]
highest_churn = customers.loc[customers['churn_rate'].idxmax()]

print('=== EXECUTIVE SUMMARY KPIs ===')
print(f"Total Revenue:      SAR {total_revenue / 1e6:,.1f}M")
print(f"Avg Satisfaction:   {avg_satisfaction:.1f} / 5.0")
print(f"Top Growth Region:  {top_growth_region['region']} at {top_growth_region['growth_pct']:.1f}%")
print(f"Highest Churn:      {highest_churn['segment']} at {highest_churn['churn_rate']:.1f}%")

# %%
# Lab 7, Task 2: Branch revenue bar chart with target line
# YOUR CODE HERE
# Hint: add plt.axvline() for the target reference line
# Use an insight title, not a topic title

# %% [markdown]
# ## Lab 8: Complete Executive Pack
#
# **Task 1:** Segment analysis -- scatter plot of churn_rate vs revenue_per_customer.
#
# **Task 2:** Regional growth -- bubble chart or bar chart showing geographic patterns.
#
# **Task 3:** Write a 3-5 sentence narrative connecting all three views.
#
# **Task 4:** Write a 2-3 sentence closing recommendation.

# %%
# Lab 8: Build your complete executive reporting pack here
# Create 2-3 charts with consistent palette and annotations

# YOUR CODE HERE
