# %% [markdown]
# # Day 2 | Segmentation, Evaluation, and Model Comparison
#
# ## Focus Areas
# - Build a customer segmentation using K-Means clustering and describe segments in business language.
# - Evaluate a trained classifier beyond headline metrics (precision-recall curves, error analysis, calibration).
# - Compare two candidate models fairly on performance, interpretability, and governance criteria.
#
# ## Reminders
# - Justify feature selection before justifying a model. Feature choice is a governance decision.
# - Scale features before clustering. K-Means is sensitive to feature magnitudes.
# - A good model comparison considers interpretability and monitoring burden, not just F1.
# - Describe segments in language a business leader would understand, not cluster IDs.
#
# ## Datasets
# - **customer_segments.csv**: AJB retail banking customers with demographic, transactional, and product-holding data.
# - **service_tickets_ml.csv**: Reuse from Day 1 for model evaluation and comparison exercises.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import (
    precision_recall_curve, roc_curve, auc,
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix
)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

DATA_DIR = Path("../data")
pd.set_option("display.max_columns", 30)
plt.rcParams["figure.figsize"] = (8, 5)

print("Setup complete.")

# %%
segments = pd.read_csv(DATA_DIR / "customer_segments.csv")
print(f"Segments shape: {segments.shape}")
print(f"Columns: {list(segments.columns)}")
print()
segments.describe()

# Also reload tickets for Labs 4 and 5
# tickets = pd.read_csv(DATA_DIR / "service_tickets_ml.csv")

# %%
# --- Lab 3: Customer Segmentation Studio ---
# Task 1: Choose segmentation features and justify each choice.
# feature_cols = ["annual_value", "transaction_frequency", "product_count"]
# X_seg = segments[feature_cols]

# Task 2: Apply scaling
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X_seg)

# Task 3: Run K-Means
# km = KMeans(n_clusters=4, random_state=42, n_init=10)
# segments["cluster"] = km.fit_predict(X_scaled)

# Task 4-5: Segment summary table
# summary = segments.groupby("cluster")[feature_cols].agg(["mean", "median", "count"])
# print(summary)

# Task 6: Write action recommendations per segment (as comments or markdown)

# --- Lab 4: Model Evaluation Deep-Dive ---
# Rebuild your Day 1 baseline, then:
# Task 1: Plot precision-recall curve
# y_proba = model.predict_proba(X_test)[:, 1]
# prec, rec, thresholds = precision_recall_curve(y_test, y_proba)
# plt.plot(rec, prec)
# plt.xlabel("Recall"); plt.ylabel("Precision")
# plt.title("Precision-Recall Curve")
# plt.show()

# Task 3: Error analysis -- categorise false positives and false negatives
# Task 5: Calibration discussion

# --- Lab 5: Model Comparison Review ---
# Train two models on the same split:
# model_lr = LogisticRegression(max_iter=1000).fit(X_train, y_train)
# model_rf = RandomForestClassifier(n_estimators=100, random_state=42).fit(X_train, y_train)

# Build comparison table:
# comparison = pd.DataFrame({
#     "Model": ["Logistic Regression", "Random Forest"],
#     "Accuracy": [accuracy_score(y_test, model_lr.predict(X_test)),
#                  accuracy_score(y_test, model_rf.predict(X_test))],
#     "F1": [f1_score(y_test, model_lr.predict(X_test)),
#            f1_score(y_test, model_rf.predict(X_test))],
#     "Interpretability": ["High", "Medium"],
#     "Governance Burden": ["Low", "Medium"]
# })
# print(comparison.to_string(index=False))

# %% [markdown]
# ## End-of-Day Reflection
#
# Answer these questions in your own words before closing the notebook.
#
# 1. Which feature contributes most to segment meaning, and how do you know?
# 2. Which segment would be easiest to misinterpret or misuse?
# 3. What is the difference between a model that scores well and a model that is ready for production?
# 4. When would the weaker model actually be the better decision?
# 5. What governance question is most likely to be missed in a model comparison?
