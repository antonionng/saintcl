# %% [markdown]
# # Day 1 | Problem Framing and Baselines
#
# ## Focus Areas
# - Define the target variable, prediction unit, and time horizon for an SLA breach prediction task.
# - Build a baseline classifier and report key evaluation metrics.
# - Interpret a confusion matrix in operational banking language.
# - Recommend a decision threshold with a clear trade-off statement.
#
# ## Reminders
# - State the business decision before you define the metric.
# - Exclude features that could leak the outcome (e.g. resolution time).
# - A baseline model should be simple. Logistic regression or a single decision tree is appropriate here.
# - Interpret every metric in terms of what it means for the operations team, not just as a number.
#
# ## Dataset
# - **service_tickets_ml.csv**: Historical AJB customer service tickets with metadata, priority levels, response times, and SLA breach indicators.
# - **model_governance_scenarios.csv**: Reference scenarios for governance discussion (used in reflection).

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay
)

DATA_DIR = Path("../data")
pd.set_option("display.max_columns", 30)
plt.rcParams["figure.figsize"] = (8, 5)

print("Setup complete.")

# %%
tickets = pd.read_csv(DATA_DIR / "service_tickets_ml.csv")
print(f"Shape: {tickets.shape}")
print(f"\nColumns: {list(tickets.columns)}")
print(f"\nTarget distribution:")
print(tickets.dtypes)
print()
tickets.head(10)

# %%
# --- Lab 1: Problem Framing ---
# Task 1: State the business decision this model would support.
# Task 2: Define the target variable (what, for which unit, over what horizon).
# Task 3: List at least five candidate input features with justification.
# Task 4: Identify at least two features to exclude and explain why.
# Task 5: Document three assumptions that must hold.
# Task 6: Identify the most important failure mode.
# Task 7: State the stakeholder group that owns the decision.
#
# Write your problem framing notes as comments or markdown in this cell,
# then use the code below to inspect candidate features.

# Inspect candidate features
print("Column summary:")
print(tickets.describe(include="all").T)

# --- Lab 2: Baseline Classification ---
# Task 1: Define the target column.
# target_col = "YOUR_TARGET_HERE"

# Task 2: Train/test split
# X = tickets[feature_cols]
# y = tickets[target_col]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Task 3: Build baseline classifier
# model = LogisticRegression(max_iter=1000)
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)

# Task 4: Report metrics
# print(f"Accuracy:  {accuracy_score(y_test, y_pred):.3f}")
# print(f"Precision: {precision_score(y_test, y_pred):.3f}")
# print(f"Recall:    {recall_score(y_test, y_pred):.3f}")
# print(f"F1:        {f1_score(y_test, y_pred):.3f}")

# Task 5-7: Confusion matrix and threshold recommendation
# cm = confusion_matrix(y_test, y_pred)
# ConfusionMatrixDisplay(cm).plot()
# plt.title("Baseline Confusion Matrix")
# plt.show()

# %% [markdown]
# ## End-of-Day Reflection
#
# Answer these questions in your own words before closing the notebook.
#
# 1. Why is problem framing the highest-leverage step in the ML workflow?
# 2. Which error type (false positive or false negative) matters most for SLA breach prediction, and why?
# 3. What would make your current metric choice unsafe in production?
# 4. If the model performed perfectly on test data, would you trust it? Why or why not?
# 5. What is one thing you would do differently if you repeated today's work?
